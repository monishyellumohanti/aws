# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
pd.Series()
# Out:
# Series([], dtype: float64)

# %%
l=["jay","raj","suraj","raj","chanda"]
type(l)
# Out:
# list

# %%
pd.Series(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 pd.Series(l)
#
# NameError: name 'l' is not defined

# %%
pd.Series(data=l,index=["A","B","C","D","E"])
# Out:
# A       jay
# B       raj
# C     suraj
# D       raj
# E    chanda
# dtype: object

# %%
d={
    "A":"jay",
    "B":"raj",
    "C":"suraj",
    "D":"raj",
    "E":"chanda"
}
pd.Series(d)
# Out:
# A       jay
# B       raj
# C     suraj
# D       raj
# E    chanda
# dtype: object

# %%
pd.Series(data=7,index=["A","B","C","D","E"])
# Out:
# A    7
# B    7
# C    7
# D    7
# E    7
# dtype: int64

# %%
d=[
    ["jay",89,25],
    ["raj",90,24],
    ["suraj",78,23],
    ["raj",87,24],
    ["chanda",90,25]
]
pd.DataFrame(d)
# Out:
#         0   1   2
# 0     jay  89  25
# 1     raj  90  24
# 2   suraj  78  23
# 3     raj  87  24
# 4  chanda  90  25

# %%
col=["names","marks","age"]
pd.DataFrame(d,columns=col)
# Out:
#     names  marks  age
# 0     jay     89   25
# 1     raj     90   24
# 2   suraj     78   23
# 3     raj     87   24
# 4  chanda     90   25

# %%
d={
    "Name":["Jay","Raj","Suraj","Raj","Chanda"],
    "Marks":[89,90,78,87,90],
    "Age":[25,24,23,24,25]
}
pd.DataFrame(d)
# Out:
#      Name  Marks  Age
# 0     Jay     89   25
# 1     Raj     90   24
# 2   Suraj     78   23
# 3     Raj     87   24
# 4  Chanda     90   25

# %%
d=np.random.randn(10,4)
df=pd.DataFrame(d,columns=["A","B","C","D"])
df
# Out:
#           A         B         C         D
# 0  0.283501  0.755853  0.665693 -0.337744
# 1 -1.655872 -0.700612 -0.394260 -1.505832
# 2  0.234848  0.022402 -0.376793  0.440928
# 3 -1.596822  0.908155 -0.465098 -0.137279
# 4 -0.648972 -0.389623 -1.821531  0.432793
# 5  0.688091 -0.381358 -0.763707  0.972765
# 6  0.529299  0.762080  1.566475  1.205792
# 7  1.693175  0.133224 -0.311236  0.156515
# 8  0.819677 -0.724386  0.877127  1.039936
# 9  1.720915 -1.096272 -1.421228 -0.801026

# %%
df.to_csv("Random_18_10.csv",index=False)

# %%
l={
    "ID":[1,2,3,4],
    "Name":["monish","neha","barun","Rommy"],
    "Marks":[50,40,60,30]
    
}
c=pd.DataFrame(l)

# %%
c=c.to_csv("students.csv",index=False)

# %%
c=pd.read_csv("students.csv")
c.head()
c.tail()
# Out:
#    ID    Name  Marks
# 0   1  monish     50
# 1   2    neha     40
# 2   3   barun     60
# 3   4   Rommy     30

# %%
df=pd.read_table("movies.csv")
df
# Out:
#     star_rating,title,content_rating,genre,duration,actors_list
# 0    9.3,The Shawshank Redemption,R,Crime,142,"[u'T...
# 1    9.2,The Godfather,R,Crime,175,"[u'Marlon Brand...
# 2    9.1,The Godfather: Part II,R,Crime,200,"[u'Al ...
# 3    9,The Dark Knight,PG-13,Action,152,"[u'Christi...
# 4    8.9,Pulp Fiction,R,Crime,154,"[u'John Travolta...
# ..                                                 ...
# 974  7.4,Tootsie,PG,Comedy,116,"[u'Dustin Hoffman',...
# 975  7.4,Back to the Future Part III,PG,Adventure,1...
# 976  7.4,Master and Commander: The Far Side of the ...
# 977  7.4,Poltergeist,PG,Horror,114,"[u'JoBeth Willi...
# 978  7.4,Wall Street,R,Crime,126,"[u'Charlie Sheen'...
#
# [979 rows x 1 columns]

# %%
df=pd.read_table("drinks.csv",sep=",")
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
# !pip install xlrd

# %%
# !pip install openpyxl

# %%
df=pd.read_excel("exbook.xlsx",sheet_name="Sheet1")
df
# Out:
#    Sr.NO                                   Books            Author  year  \
# 0      1                  The Discovery of India  Jawaharlal Nehru  1946
# 1      2  The Story of my Experiments with Truth    Mahatma Gandhi  1927
# 2      3                 Glimps of World History           J.Nehru  1934
# 3      4                       A Guide to Health    Mahatma Gandhi  1921
# 4      5                           Ignited Minds   APJ Abdul Kalam  2002
# 5      6                           Wings of Fire   APJ Abdul Kalam  1999
#
#      Price  Profit
# 0   599.95    0.30
# 1   159.00    0.30
# 2   750.46    0.24
# 3   250.00    0.25
# 4   300.00    0.10
# 5  1275.25    0.10

# %%
path="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
col=["sepal length","sepal width","petal length","petal width","class"]
pd.read_table(path,sep=",",header=None,names=col)
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
users=pd.read_table("psd.user")
col=["id","age","gender","profession","zip code"]
pd.read_table("psd.user",sep="|",header=None,names=col)
# Out:
#       id  age gender     profession zip code
# 0      1   24      M     technician    85711
# 1      2   53      F          other    94043
# 2      3   23      M         writer    32067
# 3      4   24      M     technician    43537
# 4      5   33      F          other    15213
# ..   ...  ...    ...            ...      ...
# 938  939   26      F        student    33319
# 939  940   32      M  administrator    02215
# 940  941   20      M        student    97229
# 941  942   48      F      librarian    78209
# 942  943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
pd.read_json("simple.json")
# Out:
#        name  age grade
# 0     Andew   12     A
# 1    Bhuvan   18     B
# 2   Clinton   11     A
# 3     Drake   12     C
# 4     Eisha   13     B
# 5    Farhan   22     C
# 6    Garima   11     A
# 7  Himanshu   19     A
# 8    Ishaan   10     D
# 9     Jason    9     B

# %%
pd.read_table("simple.json")
# Out:
# Empty DataFrame
# Columns: [[{"name": "Andew", "age": 12, "grade": "A"}, {"name": "Bhuvan", "age": 18, "grade": "B"}, {"name": "Clinton", "age": 11, "grade": "A"}, {"name": "Drake", "age": 12, "grade": "C"}, {"name": "Eisha", "age": 13, "grade": "B"}, {"name": "Farhan", "age": 22, "grade": "C"}, {"name": "Garima", "age": 11, "grade": "A"}, {"name": "Himanshu", "age": 19, "grade": "A"}, {"name": "Ishaan", "age": 10, "grade": "D"}, {"name": "Jason", "age": 9, "grade": "B"}]]
# Index: []

# %%
pd.read_json("simple_records.json",lines=True)
# Out:
#        name  age grade
# 0     Andew   12     A
# 1    Bhuvan   18     B
# 2   Clinton   11     A
# 3     Drake   12     C
# 4     Eisha   13     B
# 5    Farhan   22     C
# 6    Garima   11     A
# 7  Himanshu   19     A
# 8    Ishaan   10     D
# 9     Jason    9     B

# %%
df=pd.read_table("movies.csv",sep=",")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.shape
# Out:
# (979, 6)

# %%
df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
df.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
df.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
df.mean()
# Out:
# star_rating      7.889785
# duration       120.979571
# dtype: float64

# %%
df.median()
# Out:
# star_rating      7.8
# duration       117.0
# dtype: float64

# %%
df.mode()
# Out:
#    star_rating                            title content_rating  genre  \
# 0          7.6                          Dracula              R  Drama
# 1          NaN                   Les Miserables            NaN    NaN
# 2          NaN  The Girl with the Dragon Tattoo            NaN    NaN
# 3          NaN                        True Grit            NaN    NaN
#
#    duration                                        actors_list
# 0     112.0  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 1       NaN                                                NaN
# 2       NaN                                                NaN
# 3       NaN                                                NaN

# %%
l=[60,82,82,84,88,90,90,92,93,97]
df=pd.DataFrame(l)
df
# Out:
#     0
# 0  60
# 1  82
# 2  82
# 3  84
# 4  88
# 5  90
# 6  90
# 7  92
# 8  93
# 9  97

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       10 non-null     int64
# dtypes: int64(1)
# memory usage: 208.0 bytes

# %%
df.mean()
# Out:
# 0    85.8
# dtype: float64

# %%
df.median()
# Out:
# 0    89.0
# dtype: float64

# %%
df.mode()
# Out:
#     0
# 0  82
# 1  90

# %%
df.describe()
# Out:
#                0
# count  10.000000
# mean   85.800000
# std    10.293472
# min    60.000000
# 25%    82.500000
# 50%    89.000000
# 75%    91.500000
# max    97.000000
